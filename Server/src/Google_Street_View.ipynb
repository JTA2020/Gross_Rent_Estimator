# %%
from PIL import Image
import requests
URL = 'https://maps.googleapis.com/maps/api/streetview?size=1800x900&location=48.514671325683594,-123.37329864501953&fov=80&heading=70&pitch=0&key=AIzaSyBmSBRDy9dcb3fRob8BRIf3IoQZkn5ejXU'
im = Image.open(requests.get(URL, stream=True).raw)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7FABCC499C70>
